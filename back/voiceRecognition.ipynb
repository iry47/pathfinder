# %%
# Set Model Name
model_name = "linto-model"

# %%
from vosk import Model, KaldiRecognizer, SetLogLevel 

import sys
import os

import wave
import json

path = "./models/{}".format(model_name)

print(path)
print(os.path.exists(path))

if not os.path.exists(path):
    print ("Please download the model from https://alphacephei.com/vosk/models and unpack as 'model' in the current folder.")
    exit(1)

print("test")
print(sys.argv[1])

wf = wave.open("filename.wav", "rb")
#wf = wave.open("./vosk-api/python/example/test.wav", "rb")

print(wf.getnchannels() != 1 or wf.getsampwidth() != 2 or wf.getcomptype() != "NONE")

if wf.getnchannels() != 1 or wf.getsampwidth() != 2 or wf.getcomptype() != "NONE":
    print ("Audio file must be WAV format mono PCM.")
    exit (1)

model = Model(path)
rec = KaldiRecognizer(model, wf.getframerate())
rec.SetMaxAlternatives(10)
rec.SetWords(True)

while True:
    data = wf.readframes(4000)
    if len(data) == 0:
        break
    if rec.AcceptWaveform(data):
        print(rec.Result())
    else:
        print(rec.PartialResult())
# Out:
# ./models/linto-model
# True
# test
# -f
# False
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : "bonjour"
# }
# {
#   "partial" : "bonjour"
# }
# {
#   "partial" : "bonjour"
# }
# {
#   "partial" : "bonjour ceci est"
# }
# {
#   "partial" : "bonjour ceci est un"
# }
# {
#   "partial" : "bonjour ceci est un"
# }
# {
#   "partial" : "bonjour ceci est un test"
# }
# {
#   "partial" : "bonjour ceci est un test"
# }
# {
#   "partial" : "bonjour ceci est un test"
# }
# {
#   "alternatives" : [{
#       "confidence" : 410.489868,
#       "result" : [{
#           "end" : 4.560000,
#           "start" : 4.050000,
#           "word" : "bonjour"
#         }, {
#           "end" : 5.490000,
#           "start" : 5.010000,
#           "word" : "ceci"
#         }, {
#           "end" : 5.670000,
#           "start" : 5.490000,
#           "word" : "est"
#         }, {
#           "end" : 5.850000,
#           "start" : 5.670000,
#           "word" : "un"
#         }, {
#           "end" : 6.360000,
#           "start" : 5.850000,
#           "word" : "test"
#         }],
#       "text" : " bonjour ceci est un test"
#     }, {
#       "confidence" : 409.420563,
#       "result" : [{
#           "end" : 0.480000,
#           "start" : 0.000000,
#           "word" : "description"
#         }, {
#           "end" : 4.560000,
#           "start" : 4.050000,
#           "word" : "bonjour"
#         }, {
#           "end" : 5.490000,
#           "start" : 5.010000,
#           "word" : "ceci"
#         }, {
#           "end" : 5.670000,
#           "start" : 5.490000,
#           "word" : "est"
#         }, {
#           "end" : 5.850000,
#           "start" : 5.670000,
#           "word" : "un"
#         }, {
#           "end" : 6.360000,
#           "start" : 5.850000,
#           "word" : "test"
#         }],
#       "text" : "description bonjour ceci est un test"
#     }, {
#       "confidence" : 409.173767,
#       "result" : [{
#           "end" : 0.180000,
#           "start" : 0.000000,
#           "word" : "des"
#         }, {
#           "end" : 0.480000,
#           "start" : 0.180000,
#           "word" : "souvenirs"
#         }, {
#           "end" : 4.560000,
#           "start" : 4.050000,
#           "word" : "bonjour"
#         }, {
#           "end" : 5.490000,
#           "start" : 5.010000,
#           "word" : "ceci"
#         }, {
#           "end" : 5.670000,
#           "start" : 5.490000,
#           "word" : "est"
#         }, {
#           "end" : 5.850000,
#           "start" : 5.670000,
#           "word" : "un"
#         }, {
#           "end" : 6.360000,
#           "start" : 5.850000,
#           "word" : "test"
#         }],
#       "text" : "des souvenirs bonjour ceci est un test"
#     }, {
#       "confidence" : 407.594330,
#       "result" : [{
#           "end" : 0.180000,
#           "start" : 0.000000,
#           "word" : "les"
#         }, {
#           "end" : 0.480000,
#           "start" : 0.180000,
#           "word" : "souvenirs"
#         }, {
#           "end" : 4.560000,
#           "start" : 4.050000,
#           "word" : "bonjour"
#         }, {
#           "end" : 5.490000,
#           "start" : 5.010000,
#           "word" : "ceci"
#         }, {
#           "end" : 5.670000,
#           "start" : 5.490000,
#           "word" : "est"
#         }, {
#           "end" : 5.850000,
#           "start" : 5.670000,
#           "word" : "un"
#         }, {
#           "end" : 6.360000,
#           "start" : 5.850000,
#           "word" : "test"
#         }],
#       "text" : "les souvenirs bonjour ceci est un test"
#     }, {
#       "confidence" : 407.100281,
#       "result" : [{
#           "end" : 0.090000,
#           "start" : 0.000000,
#           "word" : "vous"
#         }, {
#           "end" : 0.150000,
#           "start" : 0.090000,
#           "word" : "vous"
#         }, {
#           "end" : 0.480000,
#           "start" : 0.150000,
#           "word" : "souvenez"
#         }, {
#           "end" : 4.560000,
#           "start" : 4.050000,
#           "word" : "bonjour"
#         }, {
#           "end" : 5.490000,
#           "start" : 5.010000,
#           "word" : "ceci"
#         }, {
#           "end" : 5.670000,
#           "start" : 5.490000,
#           "word" : "est"
#         }, {
#           "end" : 5.850000,
#           "start" : 5.670000,
#           "word" : "un"
#         }, {
#           "end" : 6.360000,
#           "start" : 5.850000,
#           "word" : "test"
#         }],
#       "text" : "vous vous souvenez bonjour ceci est un test"
#     }, {
#       "confidence" : 406.361389,
#       "result" : [{
#           "end" : 0.090000,
#           "start" : 0.000000,
#           "word" : "vous"
#         }, {
#           "end" : 0.480000,
#           "start" : 0.090000,
#           "word" : "détenez"
#         }, {
#           "end" : 4.560000,
#           "start" : 4.050000,
#           "word" : "bonjour"
#         }, {
#           "end" : 5.490000,
#           "start" : 5.010000,
#           "word" : "ceci"
#         }, {
#           "end" : 5.670000,
#           "start" : 5.490000,
#           "word" : "est"
#         }, {
#           "end" : 5.850000,
#           "start" : 5.670000,
#           "word" : "un"
#         }, {
#           "end" : 6.360000,
#           "start" : 5.850000,
#           "word" : "test"
#         }],
#       "text" : "vous détenez bonjour ceci est un test"
#     }, {
#       "confidence" : 405.877319,
#       "result" : [{
#           "end" : 0.180000,
#           "start" : 0.000000,
#           "word" : "je"
#         }, {
#           "end" : 0.480000,
#           "start" : 0.180000,
#           "word" : "souhaitais"
#         }, {
#           "end" : 4.560000,
#           "start" : 4.050000,
#           "word" : "bonjour"
#         }, {
#           "end" : 5.490000,
#           "start" : 5.010000,
#           "word" : "ceci"
#         }, {
#           "end" : 5.670000,
#           "start" : 5.490000,
#           "word" : "est"
#         }, {
#           "end" : 5.850000,
#           "start" : 5.670000,
#           "word" : "un"
#         }, {
#           "end" : 6.360000,
#           "start" : 5.850000,
#           "word" : "test"
#         }],
#       "text" : "je souhaitais bonjour ceci est un test"
#     }, {
#       "confidence" : 405.852539,
#       "result" : [{
#           "end" : 0.480000,
#           "start" : 0.000000,
#           "word" : "détrompez-vous"
#         }, {
#           "end" : 4.560000,
#           "start" : 4.050000,
#           "word" : "bonjour"
#         }, {
#           "end" : 5.490000,
#           "start" : 5.010000,
#           "word" : "ceci"
#         }, {
#           "end" : 5.670000,
#           "start" : 5.490000,
#           "word" : "est"
#         }, {
#           "end" : 5.850000,
#           "start" : 5.670000,
#           "word" : "un"
#         }, {
#           "end" : 6.360000,
#           "start" : 5.850000,
#           "word" : "test"
#         }],
#       "text" : "détrompez-vous bonjour ceci est un test"
#     }, {
#       "confidence" : 405.710083,
#       "result" : [{
#           "end" : 0.180000,
#           "start" : 0.000000,
#           "word" : "je"
#         }, {
#           "end" : 0.300000,
#           "start" : 0.180000,
#           "word" : "suis"
#         }, {
#           "end" : 4.560000,
#           "start" : 4.050000,
#           "word" : "bonjour"
#         }, {
#           "end" : 5.490000,
#           "start" : 5.010000,
#           "word" : "ceci"
#         }, {
#           "end" : 5.670000,
#           "start" : 5.490000,
#           "word" : "est"
#         }, {
#           "end" : 5.850000,
#           "start" : 5.670000,
#           "word" : "un"
#         }, {
#           "end" : 6.360000,
#           "start" : 5.850000,
#           "word" : "test"
#         }],
#       "text" : "je suis bonjour ceci est un test"
#     }, {
#       "confidence" : 405.594910,
#       "result" : [{
#           "end" : 0.180000,
#           "start" : 0.000000,
#           "word" : "des"
#         }, {
#           "end" : 0.480000,
#           "start" : 0.180000,
#           "word" : "sources"
#         }, {
#           "end" : 4.560000,
#           "start" : 4.050000,
#           "word" : "bonjour"
#         }, {
#           "end" : 5.490000,
#           "start" : 5.010000,
#           "word" : "ceci"
#         }, {
#           "end" : 5.670000,
#           "start" : 5.490000,
#           "word" : "est"
#         }, {
#           "end" : 5.850000,
#           "start" : 5.670000,
#           "word" : "un"
#         }, {
#           "end" : 6.360000,
#           "start" : 5.850000,
#           "word" : "test"
#         }],
#       "text" : "des sources bonjour ceci est un test"
#     }]
# }
# {
#   "partial" : ""
# }
# {
#   "partial" : ""
# }
